# %%
#尝试一下
import pandas as pd
train_df = pd.read_csv('train_set.csv', sep='\t'
                       , nrows=100
                       )
train_df.head()
# Out:
#    label                                               text
# 0      2  2967 6758 339 2021 1854 3731 4109 3792 4149 15...
# 1     11  4464 486 6352 5619 2465 4802 1452 3137 5778 54...
# 2      3  7346 4068 5074 3747 5681 6093 1777 2226 7354 6...
# 3      2  7159 948 4866 2109 5520 2490 211 3956 5520 549...
# 4      3  3646 3055 3055 2490 4659 6065 3370 5814 2465 5...

# %%
# %pylab inline

train_df['text_len'] = train_df['text'].apply(lambda x:len(x.split(' ')))
train_df.describe()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-dcd9e9996cde> in <module>
# ----> 1 get_ipython().run_line_magic('pylab', 'inline')
#       2
#       3 train_df['text_len'] = train_df['text'].apply(lambda x:len(x.split(' ')))
#       4 train_df.describe()
#       5
#
# c:\users\lionheart\ski_env1\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-110> in pylab(self, line)
#
# c:\users\lionheart\ski_env1\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
# ...

# %%
_=plt.hist(train_df['text_len'],bins=200)
plt.xlabel('text char count')
plt.title("Histogram of char count")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-06643c1c1480> in <module>
# ----> 1 _=plt.hist(train_df['text_len'],bins=200)
#       2 plt.xlabel('text char count')
#       3 plt.title("Histogram of char count")
#       4
#
# NameError: name 'plt' is not defined

# %%
train_df['label'].value_counts().plot(kind = 'bar')
plt.title('News class count')
plt.xlabel("category")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-56-75f0fbb50057> in <module>
# ----> 1 train_df['label'].value_counts().plot(kind = 'bar')
#       2 plt.title('News class count')
#       3 plt.xlabel("category")
#       4
#
# c:\users\lionheart\ski_env1\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     765
#     766     def __call__(self, *args, **kwargs):
# --> 767         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     768
#     769         x, y, kind, kwargs = self._get_call_args(
#
# c:\users\lionheart\ski_env1\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1667                 "matplotlib is required for plotting when the "
#    1668                 'default backend "matplotlib" is selected.'
# -> 1669             ) from None
#    1670
# ...

# %%
from collections import Counter
all_lines = ' '.join(list(train_df['text']))
word_count = Counter(all_lines.split(" "))
word_count.items()
word_count = sorted(word_count.items(), key=lambda d:d[1], reverse = True)
print(len(word_count))
# Out:
# 2405

# %%
word_count[0]
# Out:
# ('3750', 3702)

# %%
word_count[-1]
# Out:
# ('5034', 1)

# %%
from collections import Counter
train_df['text_unique'] = train_df['text'].apply(lambda x: ' '.join(list(set(x.split(' ')))))
all_lines = ' '.join(list(train_df['text_unique']))
word_count = Counter(all_lines.split(" "))
word_count = sorted(word_count.items(), key=lambda d:int(d[1]), reverse = True)

# %%
word_count
# Out:
# [('900', 99),
#  ('3750', 99),
#  ('648', 96),
#  ('7399', 87),
#  ('2109', 86),
#  ('2465', 86),
#  ('6122', 85),
#  ('4464', 83),
#  ('299', 81),
#  ('669', 81),
#  ('5445', 81),
#  ('3659', 80),
#  ('1699', 80),
#  ('2400', 80),
#  ('3370', 80),
#  ('4811', 79),
#  ('4939', 79),
#  ('5598', 75),
#  ('340', 73),
#  ('7495', 72),
#  ('2376', 72),
#  ('4853', 72),
#  ('4893', 70),
#  ('5491', 70),
#  ('1519', 69),
#  ('2662', 69),
#  ('7539', 68),
#  ('5948', 68),
#  ('5977', 68),
#  ('4659', 68),
#  ('5410', 68),
#  ('1903', 68),
#  ('1460', 67),
#  ('3915', 67),
#  ('5998', 67),
#  ('2252', 66),
#  ('2490', 66),
#  ('5393', 65),
#  ('2073', 65),
#  ('1375', 65),
#  ('3223', 65),
#  ('4128', 65),
#  ('4411', 65),
#  ('3800', 64),
#  ('6065', 64),
#  ('4490', 64),
#  ('619', 63),
#  ('6093', 63),
#  ('5560', 62),
#  ('1635', 62),
#  ('4516', 62),
#  ('2210', 62),
#  ('803', 62),
#  ('1866', 62),
#  ('6017', 62),
#  ('1324', 61),
#  ('5780', 61),
#  ('307', 61),
#  ('7543', 61),
# ...

# %%
print(word_count[0])
# Out:
# ('900', 99)

# %%
print(word_count[1])
# Out:
# ('3750', 99)

# %%
print(word_count[2])
# Out:
# ('648', 96)

# %%
#判断有多少个句子
num = 0
code_list = ['900','3750','648']
for i in code_list:
    num += all_lines.count(i)
num
# Out:
# 343

# %%
df = train_df.label.value_counts()
num = [*df.index]

# %%
from collections import Counter
for i in num:
    train_i = train_df[train_df['label']==i]
    all_lines_i = ' '.join(list(train_i['text']))
    word_count_i = Counter(all_lines_i.split(" "))
    word_count_i= sorted(word_count_i.items(), key=lambda d:d[1], reverse = True)
    print(word_count_i[0])
# Out:
# ('3750', 956)
# ('3750', 531)
# ('3750', 610)
# ('3750', 239)
# ('3750', 78)
# ('3750', 102)
# ('3750', 214)
# ('3750', 491)
# ('3750', 152)
# ('3750', 51)
# ('3750', 68)
# ('3750', 193)
# ('4464', 59)
# ('648', 6)
